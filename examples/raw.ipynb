# %%
import sys
sys.path.append("../../")
from root import *

# %%
df = pd.read_csv("../../data/flow/raw/cells.csv.gz")
df["layer"].value_counts()

# %%
df = pd.read_csv("../../data/flow/raw/cells.csv.gz")
xys = []
for idd in range(3, 23):
    xy = df[df["layer"] == idd][["x", "y"]].values
    xys.append(xy)

BASE = "data/flow2"
flowImport = spacemap.flow.FlowImport(BASE)
flowImport.init_xys(xys)

# %%
import sys
sys.path.append("../../")
from root import *

BASE = "data/flow2"
spacemap.init_path(BASE)
flowImport = spacemap.flow.FlowImport(BASE)
slices = flowImport.slices
mgr = spacemap.flow.AutoFlowMultiCenter4(slices, Slice.rawKey)
# spacemap.affine_block.AutoAffineImgKey.useLDM = False
mgr.affine("DF", show=True)
# spacemap.IMGCONF = {"raw": 0}
# spacemap.XYD = 10
mgr.ldm_pair(Slice.align1Key, Slice.align2Key, show=True)

# %%
export = spacemap.flow.FlowExport(slices)
spacemap.XYD = 5
spacemap.IMGCONF = {"raw": 1}
# imgs = export.export_imgs("DF", Slice.align1Key, False)
# np.save("data/flow_a1.npy", imgs)


export = spacemap.flow.FlowExport(slices)
def export_imgs(imgs, prefix):
    imgs_ = imgs.copy()
    imgs_ *= 32
    imgs_[imgs_ > 255] = 255
    imgs_ = imgs_.astype(np.uint8)
    for i in range(imgs.shape[0]):
        tiff.imwrite("data/imgs_global/%s_%d.tiff" % (prefix, i), imgs_[i])
    np.save("data/imgs_global/%s.npy" % prefix, imgs_)

# export_imgs(export.export_imgs("DF", Slice.align2Key, False), "c_4")
export_imgs(export.export_imgs("DF", Slice.finalKey, False), "c_6")

# %%
imgs_ = imgs.copy()
imgs_ *= 32
imgs_[imgs_ > 255] = 255
imgs_ = imgs_.astype(np.uint8)
for i in range(imgs.shape[0]):
    tiff.imwrite("data/imgs_global/c_4_%d.tiff" % i, imgs_[i])
